# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('retailmcq.csv')

# %% [markdown]
# those rows where Outlet_Type is Grocery Store, Outlet_size is Small and Item_Fat_Content is Low fat

# %%
data.query("Outlet_Size=='Small'").query("Item_Fat_Content=='Low Fat'").query("Outlet_Type=='Grocery Store'")
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 23             FDC37          NaN          Low Fat         0.057557
# 59             FDI26          NaN          Low Fat         0.061082
# 77             FDN48          NaN          Low Fat         0.113720
# 83             NCL18          NaN          Low Fat         0.293418
# 95             FDU04          NaN          Low Fat         0.009715
# 182            NCO17          NaN          Low Fat         0.128478
# 225            NCO07          NaN          Low Fat         0.017117
# 227            DRF27          NaN          Low Fat         0.049755
# 250            DRF15          NaN          Low Fat         0.058153
# 255            FDQ04          NaN          Low Fat         0.148393
# 284            FDJ08          NaN          Low Fat         0.193773
# 334            FDC41          NaN          Low Fat         0.204700
# 344            FDJ22          NaN          Low Fat         0.092464
# ...

# %%
data.loc[(data["Outlet_Type"]=="Grocery Store") & (data["Outlet_Size"]=="Small") & (data["Item_Fat_Content"]=="Low Fat"), ["Outlet_Type","Outlet_Size","Item_Fat_Content"]]
# Out:
#         Outlet_Type Outlet_Size Item_Fat_Content
# 23    Grocery Store       Small          Low Fat
# 59    Grocery Store       Small          Low Fat
# 77    Grocery Store       Small          Low Fat
# 83    Grocery Store       Small          Low Fat
# 95    Grocery Store       Small          Low Fat
# 182   Grocery Store       Small          Low Fat
# 225   Grocery Store       Small          Low Fat
# 227   Grocery Store       Small          Low Fat
# 250   Grocery Store       Small          Low Fat
# 255   Grocery Store       Small          Low Fat
# 284   Grocery Store       Small          Low Fat
# 334   Grocery Store       Small          Low Fat
# 344   Grocery Store       Small          Low Fat
# 364   Grocery Store       Small          Low Fat
# 371   Grocery Store       Small          Low Fat
# 393   Grocery Store       Small          Low Fat
# 405   Grocery Store       Small          Low Fat
# 430   Grocery Store       Small          Low Fat
# ...

# %%
data.iloc[(data[:,10]=="Grocery Store") & (data[:,1]=="Small") & (data[:,2]=="Low Fat"), ["Outlet_Type","Outlet_Size","Item_Fat_Content"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-5428d9e93c43> in <module>
# ----> 1 data.iloc[(data[:,10]=="Grocery Store") & (data[:,1]=="Small") & (data[:,2]=="Low Fat"), ["Outlet_Type","Outlet_Size","Item_Fat_Content"]]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
# ...

# %%
data=data.query("Outlet_Type=='Grocery Store' & Outlet_Size=='Small'&Item_Fat_Content=='Low Fat'")[["Outlet_Type","Outlet_Size","Item_Fat_Content"]]

# %%
print(data.columns.tolist())
# Out:
# ['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales']

# %%
type(data.sum())
# Out:
# pandas.core.series.Series

# %%
data.mean()
# Out:
# Series([], dtype: float64)

# %%
data.table()
data.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-f1c31950407e> in <module>
#       1
# ----> 2 data.table()
#       3 data.mean()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'table'

# %%
data.groupby("Outlet_Type",as_index=False).agg({"Item_Outlet_Sales":sum} ).sort_values("Item_Outlet_Sales",ascending=False)
# Out:
#          Outlet_Type  Item_Outlet_Sales
# 1  Supermarket Type1       1.291734e+07
# 3  Supermarket Type3       3.453926e+06
# 2  Supermarket Type2       1.851823e+06
# 0      Grocery Store       3.680343e+05

# %%
data.groupby("Outlet_Type",as_index=False).agg({"Item_Outlet_Sales":np.sum} ).sort_values("Item_Outlet_Sales",ascending=False)
# Out:
#          Outlet_Type  Item_Outlet_Sales
# 1  Supermarket Type1       1.291734e+07
# 3  Supermarket Type3       3.453926e+06
# 2  Supermarket Type2       1.851823e+06
# 0      Grocery Store       3.680343e+05

# %%
data.groupby("Outlet_Type").agg({"Item_Outlet_Sales":sum} ).sort_values("Item_Outlet_Sales")
# Out:
#                    Item_Outlet_Sales
# Outlet_Type
# Grocery Store           3.680343e+05
# Supermarket Type2       1.851823e+06
# Supermarket Type3       3.453926e+06
# Supermarket Type1       1.291734e+07

# %%
data.groupby("Outlet_Type",as_index=True).agg({"Item_Outlet_Sales":sum} ).sort("Item_Outlet_Sales")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-1d09ff609a82> in <module>
#       1
# ----> 2 data.groupby("Outlet_Type",as_index=True).agg({"Item_Outlet_Sales":sum} ).sort("Item_Outlet_Sales")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
data = pd.Series(['ML', 'DS|ML', np.nan, 'ML|SL'])

# %%
data
# Out:
# 0       ML
# 1    DS|ML
# 2      NaN
# 3    ML|SL
# dtype: object

# %%
data.str.get_dummies(sep='')
# Out:
#    D  L  M  S  |
# 0  0  1  1  0  0
# 1  1  1  1  1  1
# 2  0  0  0  0  0
# 3  0  1  1  1  1

# %%
type(data['Outlet_Type'])
# Out:
# pandas.core.series.Series

# %%
def num_missing(x): return sum(x.isnull()) 
print (data.apply(num_missing, axis=0))
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
pd.Timestamp('15-06-18')+pd.to_timedelta(365,unit='D')
# Out:
# Timestamp('2019-06-15 00:00:00')
