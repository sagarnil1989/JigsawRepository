# %%
import pandas as pd
import os
import numpy as np

# %%
data=pd.read_csv("/Users/gunnvantsaini/Documents/Work/Python/PythonTrainings/PythonForModellers/Data/Store.csv",
                encoding='latin1')

# %%
data.head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City    ...    Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson    ...          42420
# 1   Claire Gute  Consumer  United States  Henderson    ...          42420
#
#    Region       Product ID   Category Sub-Category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 1   South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
## Filter
## Groupby
## Sorting
## Select columns
# query/ logical index
data.query("Segment=='Consumer'").head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City    ...    Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson    ...          42420
# 1   Claire Gute  Consumer  United States  Henderson    ...          42420
#
#    Region       Product ID   Category Sub-Category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 1   South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
data[data['Segment']=='Consumer'].head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City    ...    Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson    ...          42420
# 1   Claire Gute  Consumer  United States  Henderson    ...          42420
#
#    Region       Product ID   Category Sub-Category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 1   South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
data.query("Ship_Mode=='Second Class'").head(2)
# Out:
#    Row_ID        Order_ID Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
#
#   Customer_Name   Segment        Country       City    ...    Postal_Code  \
# 0   Claire Gute  Consumer  United States  Henderson    ...          42420
# 1   Claire Gute  Consumer  United States  Henderson    ...          42420
#
#    Region       Product_ID   Category Sub-Category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 1   South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product_Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
## How do you remove the space in all the columns?

# %%
new_cols=[]
for i in data.columns.tolist():
    new_cols.append(i.replace(" ","_"))

# %%
new_cols
# Out:
# ['Row_ID',
#  'Order_ID',
#  'Order_Date',
#  'Ship_Date',
#  'Ship_Mode',
#  'Customer_ID',
#  'Customer_Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal_Code',
#  'Region',
#  'Product_ID',
#  'Category',
#  'Sub-Category',
#  'Product_Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
data.columns=new_cols

# %%
data.columns.tolist()
# Out:
# ['Row_ID',
#  'Order_ID',
#  'Order_Date',
#  'Ship_Date',
#  'Ship_Mode',
#  'Customer_ID',
#  'Customer_Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal_Code',
#  'Region',
#  'Product_ID',
#  'Category',
#  'Sub-Category',
#  'Product_Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
data.query("Segment=='Consumer' and City=='Henderson'").head()
# Out:
#      Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 0         1  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 1         2  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 538     539  CA-2012-134894   12/7/2012  12/11/2012  Standard Class
# 539     540  CA-2012-134894   12/7/2012  12/11/2012  Standard Class
# 996     997  CA-2012-162537  10/28/2012   11/3/2012  Standard Class
#
#     Customer_ID   Customer_Name   Segment        Country       City    ...     \
# 0      CG-12520     Claire Gute  Consumer  United States  Henderson    ...
# 1      CG-12520     Claire Gute  Consumer  United States  Henderson    ...
# 538    DK-12985  Darren Koutras  Consumer  United States  Henderson    ...
# 539    DK-12985  Darren Koutras  Consumer  United States  Henderson    ...
# 996    RD-19585        Rob Dowd  Consumer  United States  Henderson    ...
#
#     Postal_Code  Region       Product_ID         Category Sub-Category  \
# ...

# %%
### Column Selection, I want a new table with only 3 columns, 
# Customer Name, Segment and Country
data[['Customer_Name','Segment','Country']].head(2)
# Out:
#   Customer_Name   Segment        Country
# 0   Claire Gute  Consumer  United States
# 1   Claire Gute  Consumer  United States

# %%
## Find out who are 5 the most valuable customer, (sales)?
data.sort_values('Sales',ascending=False).head(5)
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 2697    2698  CA-2011-145317   3/18/2011   3/23/2011  Standard Class
# 6826    6827  CA-2013-118689   10/3/2013  10/10/2013  Standard Class
# 8153    8154  CA-2014-140151   3/24/2014   3/26/2014     First Class
# 2623    2624  CA-2014-127180  10/23/2014  10/25/2014     First Class
# 4190    4191  CA-2014-166709  11/18/2014  11/23/2014  Standard Class
#
#      Customer_ID Customer_Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#         ...     Postal_Code   Region       Product_ID    Category  \
# ...

# %%
data.sort_values(['Sales','Discount'],ascending=[False,True]).head()
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 2697    2698  CA-2011-145317   3/18/2011   3/23/2011  Standard Class
# 6826    6827  CA-2013-118689   10/3/2013  10/10/2013  Standard Class
# 8153    8154  CA-2014-140151   3/24/2014   3/26/2014     First Class
# 2623    2624  CA-2014-127180  10/23/2014  10/25/2014     First Class
# 4190    4191  CA-2014-166709  11/18/2014  11/23/2014  Standard Class
#
#      Customer_ID Customer_Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#         ...     Postal_Code   Region       Product_ID    Category  \
# ...

# %%
data.groupby('Category')['Sales'].agg([np.max,np.min]).reset_index()
# Out:
#           Category       amax   amin
# 0        Furniture   4416.174  1.892
# 1  Office Supplies   9892.740  0.444
# 2       Technology  22638.480  0.990

# %%
## Quantity > 4, large volume customers, <=4 low volume customers
def get_categories(x):
    if x>4:
        return 'HighVolume'
    else:
        return 'LowVolume'

# %%
data['Quantity'].map(get_categories).head(2)
# Out:
# 0    LowVolume
# 1    LowVolume
# Name: Quantity, dtype: object

# %%
## define the name function: un-named function
# define body
data['Quantity'].map(lambda x: "HighVolume" if x>4 else "LowVolume").head(2)
# Out:
# 0    LowVolume
# 1    LowVolume
# Name: Quantity, dtype: object

# %%
comey=pd.read_csv("/Users/gunnvantsaini/Documents/Work/Python/PythonTrainings/PythonForModellers/Data/comey.csv")

# %%
comey.head(10)
# Out:
#   Senator Party Affiliation  \
# 0    BURR        Republican
# 1    BURR        Republican
# 2    BURR        Republican
# 3    BURR        Republican
# 4    BURR        Republican
# 5    BURR        Republican
# 6    BURR        Republican
# 7    BURR        Republican
# 8    BURR        Republican
# 9    BURR        Republican
#
#                                        Full Question  Comey  \
# 0  Do you have any doubt that Russia attempted to...  COMEY
# 1  Do you have any doubt that the Russian governm...  COMEY
# 2  Do you have any doubt the Russian government w...  COMEY
# 3  Are you confident that no votes cast in the 20...  COMEY
# 4  Director Comey, did the president at any time ...  COMEY
# 5  Did any individual working for this administra...  COMEY
# 6  Director, when the president requested that yo...  COMEY
# 7  Director, is it possible that, as part of this...  COMEY
# 8  So there could be something that fits a crimin...  COMEY
# ...

# %%
### Counting the words

len("This is a sentence".split(" "))
# Out:
# 4

# %%
comey['nwords']=comey['Comey Response'].map(lambda x: len(x.split(" ")))

# %%
comey.head()
# Out:
#   Senator Party Affiliation  \
# 0    BURR        Republican
# 1    BURR        Republican
# 2    BURR        Republican
# 3    BURR        Republican
# 4    BURR        Republican
#
#                                        Full Question  Comey  \
# 0  Do you have any doubt that Russia attempted to...  COMEY
# 1  Do you have any doubt that the Russian governm...  COMEY
# 2  Do you have any doubt the Russian government w...  COMEY
# 3  Are you confident that no votes cast in the 20...  COMEY
# 4  Director Comey, did the president at any time ...  COMEY
#
#                                       Comey Response  nwords
# 0                                              None.       1
# 1                                      No, no doubt.       3
# 2                                                No.       1
# 3  I'm confident. When I left as director I had s...      15
# 4                       Not to my understanding, no.       5

# %%
comey.groupby('Party Affiliation').agg({'nwords':np.mean}).reset_index()
# Out:
#   Party Affiliation     nwords
# 0          Democrat  43.309091
# 1       Independent  23.350000
# 2        Republican  25.875000

# %%
## Create column that talks about the length of question
comey['nques']=comey['Full Question'].map(lambda x: len(x.split(" ")))

# %%
comey.head()
# Out:
#   Senator Party Affiliation  \
# 0    BURR        Republican
# 1    BURR        Republican
# 2    BURR        Republican
# 3    BURR        Republican
# 4    BURR        Republican
#
#                                        Full Question  Comey  \
# 0  Do you have any doubt that Russia attempted to...  COMEY
# 1  Do you have any doubt that the Russian governm...  COMEY
# 2  Do you have any doubt the Russian government w...  COMEY
# 3  Are you confident that no votes cast in the 20...  COMEY
# 4  Director Comey, did the president at any time ...  COMEY
#
#                                       Comey Response  nwords  nques
# 0                                              None.       1     14
# 1                                      No, no doubt.       3     26
# 2                                                No.       1     18
# 3  I'm confident. When I left as director I had s...      15     14
# 4                       Not to my understanding, no.       5     23

# %%
comey.groupby('Party Affiliation').agg({'nques':np.mean})
# Out:
#                        nques
# Party Affiliation
# Democrat           37.236364
# Independent        29.500000
# Republican         39.839286

# %%
data.head(2)
# Out:
#    Row_ID        Order_ID Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
#
#   Customer_Name   Segment        Country       City    ...    Postal_Code  \
# 0   Claire Gute  Consumer  United States  Henderson    ...          42420
# 1   Claire Gute  Consumer  United States  Henderson    ...          42420
#
#    Region       Product_ID   Category Sub-Category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 1   South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product_Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
data.dtypes
# Out:
# Row_ID             int64
# Order_ID          object
# Order_Date        object
# Ship_Date         object
# Ship_Mode         object
# Customer_ID       object
# Customer_Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_Code        int64
# Region            object
# Product_ID        object
# Category          object
# Sub-Category      object
# Product_Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
data['Ship_Date']=pd.to_datetime(data['Ship_Date'])
data['Order_Date']=pd.to_datetime(data['Order_Date'])

# %%
data.dtypes
# Out:
# Row_ID                    int64
# Order_ID                 object
# Order_Date       datetime64[ns]
# Ship_Date        datetime64[ns]
# Ship_Mode                object
# Customer_ID              object
# Customer_Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal_Code               int64
# Region                   object
# Product_ID               object
# Category                 object
# Sub-Category             object
# Product_Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
data['Order_Date'].dt.weekday.head(2)
# Out:
# 0    5
# 1    5
# Name: Order_Date, dtype: int64

# %%
data['interval']=data['Ship_Date']-data['Order_Date']

# %%
data[data['interval']>='4 days'].shape[0]/data.shape[0]
# Out:
# 0.6772063237942766

# %%
fdelays=pd.read_csv("/Users/gunnvantsaini/Documents/Work/Python/PythonTrainings/PythonForModellers/Data/FlightDelays.csv")

# %%
fdelays.head()
# Out:
#    schedtime carrier  deptime dest  distance        date  flightnumber origin  \
# 0       1455      OH     1455  JFK       184  01-01-2004          5935    BWI
# 1       1640      DH     1640  JFK       213  01-01-2004          6155    DCA
# 2       1245      DH     1245  LGA       229  01-01-2004          7208    IAD
# 3       1715      DH     1709  LGA       229  01-01-2004          7215    IAD
# 4       1039      DH     1035  LGA       229  01-01-2004          7792    IAD
#
#    weather  tailnu   delay
# 0        0  N940CA  ontime
# 1        0  N405FJ  ontime
# 2        0  N695BR  ontime
# 3        0  N662BR  ontime
# 4        0  N698BR  ontime

# %%
### How many flights were delayed on Weekends?
### How many flights were on time on a Friday?
### How many flights were delayed across all Carriers

# %%
fdelays['date']=pd.to_datetime(fdelays['date'])

# %%
fdelays['weekday']=fdelays['date'].dt.weekday

# %%
fdelays.query("weekday>=5 and delay=='delayed'").shape[0]
# Out:
# 92

# %%
fdelays.query("weekday==4 and delay=='ontime'").shape[0]
# Out:
# 316

# %%
fdelays.query("delay=='delayed'").groupby('carrier').size()
# Out:
# carrier
# CO     26
# DH    137
# DL     47
# MQ     80
# OH      4
# RU     94
# UA      5
# US     35
# dtype: int64

# %%
fdelays.query("delay=='delayed'").groupby('carrier').size()
# Out:
# carrier
# CO     26
# DH    137
# DL     47
# MQ     80
# OH      4
# RU     94
# UA      5
# US     35
# dtype: int64

# %%
data.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Region       Product_ID         Category Sub-Category  \
# ...

# %%
# data['col'].map()
# Loop both columns and rows (axis)
# data.apply()
def get_new_sales(row):
    if row['Ship_Mode']=='First Class':
        return row['Sales']-10
    else:
        return row['Sales']

# %%
data[['col','col']].apply(get_new_sales,axis=1)
# Out:
# 0        261.9600
# 1        731.9400
# 2         14.6200
# 3        957.5775
# 4         22.3680
# 5         48.8600
# 6          7.2800
# 7        907.1520
# 8         18.5040
# 9        114.9000
# 10      1706.1840
# 11       911.4240
# 12        15.5520
# 13       407.9760
# 14        68.8100
# 15         2.5440
# 16       665.8800
# 17        55.5000
# 18         8.5600
# 19       213.4800
# 20        22.7200
# 21        19.4600
# 22        60.3400
# 23        71.3720
# 24      1044.6300
# 25        11.6480
# 26        90.5700
# 27      3083.4300
# 28         9.6180
# 29       124.2000
#           ...
# 9964      13.4000
# 9965       4.9800
# 9966     109.6900
# 9967      40.2000
# 9968     735.9800
# 9969      22.7500
# 9970     119.5600
# 9971     140.7500
# 9972      99.5680
# 9973     271.9600
# 9974      18.6900
# 9975      13.3600
# 9976     249.5840
# 9977      13.8600
# 9978      13.3760
# 9979     437.4720
# 9980      85.9800
# 9981       6.5200
# 9982      35.5600
# ...

# %%
dl=pd.read_csv("/Users/gunnvantsaini/Desktop/Bootcamp 5/Data Manipulation R2/Data/dl.csv")

# %%
dl.head(2)
# Out:
#                                  company  \
# 0  Miracle Corporate Solutions Pvt. Ltd.
# 1           Vartemis Consulting Services
#
#                                          designation experience  \
# 0  Part Time -urgent-machine Learning /deep Learning    1-6 yrs
# 1  Senior Data Scientist - Machine Learning & Dee...   7-12 yrs
#
#            location                                             skills  \
# 0  Delhi NCR, Noida  trainer, Training, corporate trainer, Machine ...
# 1              Pune  Deep Learning, Neural Networks, Machine Learni...
#
#                            salary  posted_on  \
# 0      3,00,000 - 7,00,000 P.A.            1
# 1                  Not disclosed           3
#
#                                           scraped_on  \
# 0  2018-08-122018-08-122018-08-122018-08-122018-0...
# 1  2018-08-122018-08-122018-08-122018-08-122018-0...
#
#                                                  url
# 0  https://www.naukri.com/job-listings-Part-Time-...
# ...

# %%
exp=dl[dl['experience']!="Experience not listed"]['experience']

# %%
le=exp.map(lambda x: x.replace("yrs"," ")).map(lambda x:x.split("-")[0])

# %%
ue=exp.map(lambda x: x.replace("yrs"," ")).map(lambda x:x.split("-")[1])

# %%
le.dtype
# Out:
# dtype('O')

# %%
ue.dtype
# Out:
# dtype('O')

# %%
le.astype('float').mean()
# Out:
# 4.428571428571429

# %%
ue.astype('float').mean()
# Out:
# 8.693877551020408
